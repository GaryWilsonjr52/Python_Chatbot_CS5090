# %% [markdown]
# <a href="https://colab.research.google.com/github/GaryWilsonjr52/Python_Chatbot_CS5090/blob/main/collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Clone the repo with all files
#
# !pip install torch numpy transformers datasets tiktoken wandb tqdm

# %%
# %%capture
# !git clone https://github.com/GaryWilsonjr52/Python_Chatbot_CS5090.git

# %% [markdown]
# train a test of the gpt

# %%
# %cd /content/Python_Chatbot_CS5090/nanoGPT
# !python data/shakespeare_char/prepare.py
# Out:
# /content/Python_Chatbot_CS5090/nanoGPT
# length of dataset in characters: 1,115,394
# all the unique characters:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65
# train has 1,003,854 tokens
# val has 111,540 tokens

# %%
# !python train.py --out_dir=shakespeare_char_out --dataset=shakespeare_char --device=cuda --compile=False --n_layer=6 --n_head=6 --n_embd=384 --vocab-size=8192 -dtype='bfloat16' --max_iters=2,480,000,000
# Out:
# Overriding: out_dir = shakespeare_char_out
# Overriding: dataset = shakespeare_char
# Overriding: device = cuda
# Overriding: compile = False
# Overriding: eval_iters = 20
# Overriding: log_interval = 10
# Overriding: block_size = 64
# Overriding: batch_size = 12
# Overriding: n_layer = 4
# Overriding: n_head = 4
# Overriding: n_embd = 128
# Overriding: max_iters = 2000
# tokens per iteration will be: 30,720
# found vocab_size = 65 (inside data/shakespeare_char/meta.pkl)
# Initializing a new model from scratch
# number of parameters: 0.80M
# /content/Python_Chatbot_CS5090/nanoGPT/train.py:196: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# num decayed parameter tensors: 18, with 802,944 parameters
# num non-decayed parameter tensors: 9, with 1,152 parameters
# using fused AdamW: True
# step 0: train loss 4.1677, val loss 4.1649
# ...

# %%
# !python sample.py --out_dir=shakespeare_char_out --device=cuda
# Out:
# Overriding: out_dir = shakespeare_char_out
# Overriding: device = cuda
# number of parameters: 0.80M
# Loading meta from data/shakespeare_char/meta.pkl...
#
#
# ANGELO:
# Ay, come, where you that set be your hands the ludge
# Takes a this foul of her back that a endward,
# And for a with must of the office of the land;
# Who carishe send, will it the lost be the know.
#
# WARWICK:
# Well, no mean this might in the princess,
# why hold not norm patient sonsething, to the leove--
# A what piice o' the dost was in him he poor of his guirly
# And not the son; if he must with alloody for her secure?
#
# Provost:
# Hast you say advance.
#
# EDWARD:
# I have knear thy brother, and for th
# ---------------
#
# Messenger:
# Amen, thou come and me! I have seem 'twas your life,
# That wounds in this live body.
#
# TYBALT:
# I my shout might to England lord.
#
# SORQUEEN PERDITA:
# I that did scatch'd in meedy boy:
# Poin in thou fear, and you, may lords!
#
# ROMUMEO:
# ...
