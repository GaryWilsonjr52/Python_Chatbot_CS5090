# %% [markdown]
# <a href="https://colab.research.google.com/github/GaryWilsonjr52/Python_Chatbot_CS5090/blob/main/collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Clone the repo with all files
#
# !pip install torch numpy transformers datasets tiktoken wandb tqdm

# %%
# %%capture
# !git clone https://github.com/GaryWilsonjr52/Python_Chatbot_CS5090.git

# %% [markdown]
# prepare the python training data

# %%
# %cd /content/Python_Chatbot_CS5090/nanoGPT
# !python /content/Python_Chatbot_CS5090/training_data/prepare.py
# Out:
# /content/Python_Chatbot_CS5090/nanoGPT
# dataset directory: /content/Python_Chatbot_CS5090/training_data/files
# Found 368 Python files.
# Length of dataset in characters: 728,555
# Training custom BPE tokenizer (vocab_size=8192)...
# [00:00:00] Tokenize words                 ██████████████████ 13116    /    13116
# [00:00:00] Count pairs                    ██████████████████ 13116    /    13116
# [00:00:00] Compute merges                 ██████████████████ 8010     /     8010
# Saved tokenizer config to /content/Python_Chatbot_CS5090/training_data/tokenizer.json
# Encoding dataset...
# Dataset has 209,989 tokens
# Train has 188,990 tokens
# Val has 20,999 tokens
# Preparation complete! train.bin, val.bin, and meta.pkl saved.

# %%
# !python train.py --out_dir=/content/training_out --dataset=/content/Python_Chatbot_CS5090/training_data/ --log_interval=10 --device=cuda --compile=False --n_layer=6 --n_head=6 --n_embd=384 --dtype='bfloat16' --max_iters=2000
# Out:
# Overriding: out_dir = /content/training_out
# Overriding: dataset = /content/Python_Chatbot_CS5090/training_data/
# Overriding: log_interval = 10
# Overriding: device = cuda
# Overriding: compile = False
# Overriding: n_layer = 6
# Overriding: n_head = 6
# Overriding: n_embd = 384
# Overriding: dtype = bfloat16
# Overriding: max_iters = 2000
# tokens per iteration will be: 491,520
# found vocab_size = 8192 (inside /content/Python_Chatbot_CS5090/training_data/meta.pkl)
# Initializing a new model from scratch
# number of parameters: 13.77M
# /content/Python_Chatbot_CS5090/nanoGPT/train.py:196: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# num decayed parameter tensors: 26, with 14,155,776 parameters
# num non-decayed parameter tensors: 13, with 4,992 parameters
# using fused AdamW: True
# step 0: train loss 9.0810, val loss 9.0740

# %%
# !python sample.py --out_dir=/content/training_out --device=cuda
