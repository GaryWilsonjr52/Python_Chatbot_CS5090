# %% [markdown]
# <a href="https://colab.research.google.com/github/GaryWilsonjr52/Python_Chatbot_CS5090/blob/main/collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Clone the repo with all files

# %%
# %%capture
# !git clone https://github.com/GaryWilsonjr52/Python_Chatbot_CS5090.git

# %% [markdown]
# prepare the python training data

# %%
# %cd /content/Python_Chatbot_CS5090/nanoGPT
# !python /content/Python_Chatbot_CS5090/training_data/prepare.py

# %% [markdown]
# Start the training

# %%
# !python train.py --out_dir=/content/training_out --dataset=/content/Python_Chatbot_CS5090/training_data/ --log_interval=5 --eval_interval=250 --block_size=1024 --batch_size=16 --gradient_accumulation_steps=16 --device=cuda --compile=False --n_layer=6 --n_head=6 --n_embd=384 --dtype='bfloat16' --max_iters=2000
# Out:
# Overriding: out_dir = /content/training_out
# Overriding: dataset = /content/Python_Chatbot_CS5090/training_data/
# Overriding: init_from = resume
# Overriding: log_interval = 5
# Overriding: eval_interval = 250
# Overriding: block_size = 1024
# Overriding: batch_size = 16
# Overriding: gradient_accumulation_steps = 16
# Overriding: device = cuda
# Overriding: compile = False
# Overriding: n_layer = 6
# Overriding: n_head = 6
# Overriding: n_embd = 384
# Overriding: dtype = bfloat16
# Overriding: max_iters = 2000
# tokens per iteration will be: 262,144
# found vocab_size = 8192 (inside /content/Python_Chatbot_CS5090/training_data/meta.pkl)
# Resuming training from /content/training_out
# Traceback (most recent call last):
#   File "/content/Python_Chatbot_CS5090/nanoGPT/train.py", line 162, in <module>
#     checkpoint = torch.load(ckpt_path, map_location=device)
#   File "/usr/local/lib/python3.13/dist-packages/torch/serialization.py", line 1530, in load
# ...

# %% [markdown]
# Resume the training if stopped

# %%
# !python train.py --out_dir=/content/training_out --dataset=/content/Python_Chatbot_CS5090/training_data/ --init_from='resume' --log_interval=5 --eval_interval=250 --block_size=1024 --batch_size=16 --gradient_accumulation_steps=16 --device=cuda --compile=False --n_layer=6 --n_head=6 --n_embd=384 --dtype='bfloat16' --max_iters=2000

# %%
# !python sample.py --out_dir=/content/training_out --device=cuda
